# %% [markdown]
# # Virtual Metering

# %% [markdown]
# Actual well production data is recorded after wells go on production. The production was modelled in Prosper, a well flow simulator, which attempted to replicate the metered production values using downhole and wellhead pressures and temperatures along with CGR and WGR, in order to better understand the well physics. Prosper modelling takes a lot of effort to set up and calibrate and it also takes a long time to run when large volumes of data are being simulated. Consequently, the sampling frequency was reduced to once daily (which still took a few hours to simulate 60 days of production. Using a Random Forest model is quite straightforward and the calculation time is extremely rapid. This would allow the sampling frequency to be increased and the model could be further integrated into a larger workflow.
#
# It should be noted, though, that the machine learning model tells us nothing about the actual physical behaviour. Machine learning tools are based on statistical matches using coefficients, whereas a Prosper model is physics-based.
#
# There are, therefore, two approaches that could be taken:
# - Train the ML model on metered (actual measured) production
# - Train the ML model on simulated production
#
# If we train on metered production, using verified and trusted data points, then the ML model could be run in tandem to the flow meter. If the metered production and the ML production deviate, this could indicate a problem with the meter or a physical change to the system, indicating a need for further investigation.
#
# If we train in simulated production, then the ML model could be run in tandem to the flow meter as a form of virtual metering, which again verifies the quality of the flow meter.
#
# In reality, both methods are so easy to implement that both could be used and cross-checked.

# %% [markdown]
# ## Load the Production Data

# %%
# Load common libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
# %matplotlib inline
# %config InlineBackend.figure_format ='retina'

# %%
# Load ML libraries
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor

# %%
# Load metered data
df_meter = pd.read_csv('meter_test.csv')

# %%
df_meter.head()
# Out:
#                   Time       PDHG-P       PDHG-T          WHP          WHT  \
# 0             Comments    SLB Gauge    SLB Gauge     Wellhead     Wellhead
# 1  dd/mm/yyyy hh:mm:ss         psia        deg F         psia        deg F
# 2   01-Jan-17 06:00:00  4788.886719    198.16353  4007.383057  150.2516312
# 3   02-Jan-17 06:00:00  4990.861328  198.7040436  4268.623096  142.5664818
# 4   03-Jan-17 06:00:00  5003.490234  199.0703964  4286.916578  149.1222504
#
#           Qgas        Qcond       Qwater
# 0     MPM Rate     MPM Rate     MPM Rate
# 1      mmscf/d          bbl          bbl
# 2  70.42371368  138.0793915  39.74084473
# 3  57.60831451  85.78764343  33.25482178
# 4   56.0139389   90.4666214  38.22122955

# %%
df_meter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Data columns (total 8 columns):
# Time      154 non-null object
# PDHG-P    154 non-null object
# PDHG-T    154 non-null object
# WHP       154 non-null object
# WHT       154 non-null object
# Qgas      154 non-null object
# Qcond     154 non-null object
# Qwater    154 non-null object
# dtypes: object(8)
# memory usage: 9.7+ KB

# %%
# Preprocess data
df_meter = df_meter.drop([0,1])
df_meter = df_meter.set_index('Time')
df_meter.index = pd.to_datetime(df_meter.index)
df_meter = df_meter.astype('float')

# %%
# Load simulated data calculated using Prosper
df_sim = pd.read_csv('meter_calc.csv')

# %%
# Data preprocessing
df_sim = df_sim.drop([0,1])
df_sim['Time'] = pd.to_datetime(df_sim['Time'])
df_sim = df_sim.set_index('Time')
df_sim = df_sim.astype('float')

# %%
df_sim.head()
# Out:
#                         Qgas.i
# Time
# 2017-01-01 06:00:00  70.423714
# 2017-01-02 06:00:00  59.379181
# 2017-01-03 06:00:00  49.309915
# 2017-01-04 06:00:00  59.136544
# 2017-01-05 06:00:00  56.323635

# %%
# Merge the dataframes
df = pd.merge(df_meter, df_sim, left_index=True, right_index=True)

# %%
df.rename(columns={'Qgas.i':'Qg_sim', 'Qgas':'Qg_meter'}, inplace=True)

# %%
df['CGR'] = df.Qcond / df.Qgas
df['WGR'] = df.Qwater/ df.Qgas

# %%
df.CGR.plot()
df.WGR.plot()
plt.legend()
plt.show()

# %%
df.head()
# Out:
#                           PDHG-P      PDHG-T          WHP         WHT  \
# Time
# 2017-01-01 06:00:00  4788.886719  198.163530  4007.383057  150.251631
# 2017-01-02 06:00:00  4990.861328  198.704044  4268.623096  142.566482
# 2017-01-03 06:00:00  5003.490234  199.070396  4286.916578  149.122250
# 2017-01-04 06:00:00  4984.001465  199.066153  4262.622940  139.118629
# 2017-01-05 06:00:00  4978.165527  199.162283  4259.095260  145.619129
#
#                           Qgas       Qcond     Qwater     Qg_sim
# Time
# 2017-01-01 06:00:00  70.423714  138.079392  39.740845  70.423714
# 2017-01-02 06:00:00  57.608315   85.787643  33.254822  59.379181
# 2017-01-03 06:00:00  56.013939   90.466621  38.221230  49.309915
# 2017-01-04 06:00:00  56.452805  106.983017  35.447380  59.136544
# 2017-01-05 06:00:00  56.323635  101.442688  23.743343  56.323635

# %% [markdown]
# ## Train Model on Metered Production

# %% [markdown]
# Can we drop Q and CGR WGR to simulate unreliable meter?

# %% [markdown]
# ## Train Model on Simulated Production

# %%
# Copy data to X
X = df.drop(['Qgas'], axis=1)

# %%
# Generate the target variable.
y = X.pop('Qg_sim')

# %%
# Train Test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)

# %%
# Instantiate Standard Scaler
ss = StandardScaler()

# %%
# Scale the training set
Xs_train = ss.fit_transform(X_train)

# %%
# Instantiate Random Forest Regressor
model = RandomForestRegressor(n_jobs=-1)

# %%
model.fit(Xs_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
model.score(Xs_train, y_train)
# Out:
# 0.9959636955707306

# %%
# Scale the test set
Xs_test = ss.transform(X_test)

# %%
model.score(Xs_test, y_test)
# Out:
# 0.5727108314045403

# %%
# Scale the entire data set
Xs = ss.transform(X)

# %%
# Predict the values for the entire data set to compare against actual data
ypred = model.predict(Xs)
# Ensure production is not negative
ypred = ypred.clip(0)

# %%
# Set up a dataframe with real and predicted production values
qc = pd.DataFrame({'real':y, 'pred':ypred})
qc['error'] = qc.real - qc.pred
qc.head()
# Out:
#                           real       pred     error
# Time
# 2017-01-01 06:00:00  70.423714  66.785446  3.638268
# 2017-01-02 06:00:00  59.379181  58.166867  1.212314
# 2017-01-03 06:00:00  49.309915  52.075591 -2.765677
# 2017-01-04 06:00:00  59.136544  58.682424  0.454120
# 2017-01-05 06:00:00  56.323635  56.093200  0.230435

# %%
# Set up a dateframe with feature importances
coef_df = pd.DataFrame({'names':X.columns,'coef':model.feature_importances_})

# %%
sns.barplot(x='coef', y='names', data=coef_df.sort_values(by='coef',ascending=False))
plt.title('Feature Importance');

# %%
sns.lmplot(x = 'real', y='pred', data=qc)
plt.title('Prediction vs Actual');

# %%
sns.lmplot(x='real', y='error', data=qc)
plt.title('Error Distribution');

# %%
sns.distplot(qc['error']);
# Out:
# /Users/telamon/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
qc.drop(['error'],axis=1).plot();

# %%
fig, ax = plt.subplots(ncols=1, nrows=3, figsize=(10,10), sharex=True)

df['PDHG-P'].plot(ax=ax[0], color='red', legend=True)
df['PDHG-T'].plot(ax=ax[1], color='green', legend=True)
df['WHP'].plot(ax=ax[0], color='blue', legend=True)
df['WHT'].plot(ax=ax[1], color='black', legend=True)
df['Qgas'].plot(ax=ax[2], color='red', legend=True)
plt.show()

# %%
df['Qg_pred'] = ypred

# %%
plt.figure(figsize=(10,10))
df['Qgas'].plot(legend=True)
df['Qg_sim'].plot(legend=True)
df['Qg_pred'].plot(legend=True)
plt.show()

# %%
score_prosper = r2_score(df['Qgas'], df['Qg_sim'])
score_rforest = r2_score(df['Qgas'], df['Qg_pred'])
score_rfprosper = r2_score(df['Qg_sim'], df['Qg_pred'])

# %%
print('R2 Score')
print('--------')
print('Prosper Prediction of Qgas: {}'.format(round(score_prosper,3)))
print('Random Forest Prediction of Qgas: {}'.format(round(score_rforest,3)))
print('Random Forest Prediction of Qg_sim(Prosper): {}'.format(round(score_rfprosper,3)))
# Out:
# R2 Score
# --------
# Prosper Prediction of Qgas: 0.957
# Random Forest Prediction of Qgas: 0.872
# Random Forest Prediction of Qg_sim(Prosper): 0.915
